# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\zomato.csv")
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.head(7)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/rosewood-inte...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  19/1, New Timberyard Layout, Beside Satellite ...
#
#                                               name online_order book_table  \
# ...

# %%
df.tail(7)
# Out:
#                                                      url  \
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51710  2E2, 4th Cross Road, Devasandra Industrial Est...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
# ...

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %% [markdown]
# ### Deleting Redundant Columns

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
columns_being_dropped = ['url', 'address', 'votes', 'phone', 'location', 'rest_type', 'cuisines', 'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)']

# %%
df.shape
# Out:
# (51717, 17)

# %%
len(columns_being_dropped)
# Out:
# 11

# %% [markdown]
# ### Dropping Columns

# %%
columns_being_dropped
# Out:
# ['url',
#  'address',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'cuisines',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.drop(columns = columns_being_dropped, inplace = True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %% [markdown]
# ### Renaming Columns as Needed

# %%
df.rename(columns = {"rate":"rating"}, inplace = True)

# %%
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rating                                         dish_liked  \
# ...

# %%
for index in df.columns:
    print(index.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rating
# Dish_liked
# Approx_cost(for two people)

# %%
modified_column_names= []
for index in df.columns:
    modified_column_names.append(index.capitalize())

# %%
modified_column_names
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rating',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
df.columns = modified_column_names

# %%
df
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table  Rating                                         Dish_liked  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Online_order', 'Book_table', 'Rating', 'Dish_liked',
#        'Approx_cost(for two people)'],
#       dtype='object')

# %% [markdown]
# ### Dropping the Duplicates

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712     True
# 51713     True
# 51714    False
# 51715     True
# 51716     True
# Length: 51717, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 32808

# %%
df.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
df.duplicated().head(7)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Removing Nan Values

# %%
df.isna()
# Out:
#         Name  Online_order  Book_table  Rating  Dish_liked  \
# 0      False         False       False   False       False
# 1      False         False       False   False       False
# 2      False         False       False   False       False
# 3      False         False       False   False       False
# 4      False         False       False   False       False
# ...      ...           ...         ...     ...         ...
# 51631  False         False       False   False        True
# 51632  False         False       False   False        True
# 51641  False         False       False   False        True
# 51677  False         False       False   False       False
# 51714  False         False       False    True        True
#
#        Approx_cost(for two people)
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# ...

# %%
df.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rating                          2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Name                           0
# Online_order                   0
# Book_table                     0
# Rating                         0
# Dish_liked                     0
# Approx_cost(for two people)    0
# dtype: int64

# %%
df
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#        Rating                                         Dish_liked  \
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#       index                                         Name Online_order  \
# 0         0                                        Jalsa          Yes
# 1         1                               Spice Elephant          Yes
# 2         2                              San Churro Cafe          Yes
# 3         3                        Addhuri Udupi Bhojana           No
# 4         4                                Grand Village           No
# ...     ...                                          ...          ...
# 8245  51611                                    Chung Wah           No
# 8246  51617                              Breakfast House           No
# 8247  51620                               Fujian Express          Yes
# 8248  51628  Nook - Aloft Bengaluru Cessna Business Park           No
# 8249  51677                                      Bhagini           No
#
#      Book_table  Rating                                         Dish_liked  \
# ...

# %%
df.drop(columns = "index", inplace = True)

# %%
df
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#       Rating                                         Dish_liked  \
# ...

# %% [markdown]
# ### Cleaning Individual Column as Needed

# %%
df["Rating"][7]
# Out:
# '4.0/5'

# %%
type(df["Rating"][7])
# Out:
# str

# %%
df["Rating"]
# Out:
# 0        4.1/5
# 1        4.1/5
# 2        3.8/5
# 3        3.7/5
# 4        3.8/5
#          ...
# 8245    2.5 /5
# 8246    3.6 /5
# 8247    3.8 /5
# 8248    4.2 /5
# 8249    2.5 /5
# Name: Rating, Length: 8250, dtype: object

# %%
df["Rating"] = df["Rating"].str.replace(" ","")

# %%
df["Rating"] = df["Rating"].str.replace("/"," out of ")

# %%
df
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#             Rating                                         Dish_liked  \
# ...

# %% [markdown]
# ### Checking For Some more Needed Changes

# %%
df
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#             Rating                                         Dish_liked  \
# ...

# %%
df["Online_order"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: object

# %%
df["Online_order"] = df["Online_order"].apply(lambda x:1 if x =="Yes" else 0)

# %%
df
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
df.to_csv("modifed_cleaned_zomato_dataset.csv")

# %%
pd.read_csv("modifed_cleaned_zomato_dataset.csv")
# Out:
#       Unnamed: 0                                         Name  Online_order  \
# 0              0                                        Jalsa             1
# 1              1                               Spice Elephant             1
# 2              2                              San Churro Cafe             1
# 3              3                        Addhuri Udupi Bhojana             0
# 4              4                                Grand Village             0
# ...          ...                                          ...           ...
# 8245        8245                                    Chung Wah             0
# 8246        8246                              Breakfast House             0
# 8247        8247                               Fujian Express             1
# 8248        8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249        8249                                      Bhagini             0
#
#      Book_table        Rating  \
# ...

# %%
df.to_csv("modifed_cleaned_zomato_dataset_no_index.csv", index = False)

# %%
pd.read_csv("modifed_cleaned_zomato_dataset_no_index.csv")
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
df.to_excel("modifed_cleaned_zomato_dataset_excel.xlsx")

# %%
df.to_excel("modifed_cleaned_zomato_dataset_excel_no_index.xlsx", index = False)
